# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_mean_std(dfs, field, length):
    arr = np.array(
            [dfs[i][field][:length] for i in range(len(dfs))])
    mean = np.mean(arr, axis=0)
    std = np.std(arr, axis=0)
    
    return mean, std

# %% [markdown]
# # Fig 11 Results

# %%
fig11_tpg_1 = pd.read_csv('../results/fig11/tpg/0.csv')
fig11_tpg_2 = pd.read_csv('../results/fig11/tpg/1.csv')
fig11_tpg_3 = pd.read_csv('../results/fig11/tpg/2.csv')
fig11_tpg_4 = pd.read_csv('../results/fig11/tpg/3.csv')
fig11_tpg_5 = pd.read_csv('../results/fig11/tpg/4.csv')
fig11_tpgs = [fig11_tpg_1, fig11_tpg_2, fig11_tpg_3, fig11_tpg_4, fig11_tpg_5]

fig11_qtpg_1 = pd.read_csv('../results/fig11/qtpg/0.csv')
fig11_qtpg_2 = pd.read_csv('../results/fig11/qtpg/1.csv')
fig11_qtpg_3 = pd.read_csv('../results/fig11/qtpg/2.csv')
fig11_qtpg_4 = pd.read_csv('../results/fig11/qtpg/3.csv')
fig11_qtpg_5 = pd.read_csv('../results/fig11/qtpg/4.csv')
fig11_qtpgs = [fig11_qtpg_1, fig11_qtpg_2, fig11_qtpg_3, fig11_qtpg_4, fig11_qtpg_5]

fig11_lqtpg_1 = pd.read_csv('../results/fig11/lqtpg/0.csv')
fig11_lqtpg_2 = pd.read_csv('../results/fig11/lqtpg/1.csv')
fig11_lqtpg_3 = pd.read_csv('../results/fig11/lqtpg/2.csv')
fig11_lqtpg_4 = pd.read_csv('../results/fig11/lqtpg/3.csv')
fig11_lqtpg_5 = pd.read_csv('../results/fig11/lqtpg/4.csv')
fig11_lqtpgs = [fig11_lqtpg_1, fig11_lqtpg_2, fig11_lqtpg_3, fig11_lqtpg_4, fig11_lqtpg_5]

# %% [markdown]
# ## gp

# %%
for i in range(len(fig11_tpgs)):
    plt.plot(fig11_tpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("tpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig11_tpgs)):
    plt.plot(fig11_tpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("gp Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## qtpg

# %%
for i in range(len(fig11_qtpgs)):
    plt.plot(fig11_qtpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("qtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig11_qtpgs)):
    plt.plot(fig11_qtpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("qtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## lqtpg

# %%
for i in range(len(fig11_lqtpgs)):
    plt.plot(fig11_lqtpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig11_lqtpgs)):
    plt.plot(fig11_lqtpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## All methods together, averaged over the 5 runs

# %%
fig11_tpg_average_runs, fig11_tpg_average_std = get_mean_std(fig11_tpgs, 'average_score', 50)
fig11_qtpg_average_runs, fig11_qtpg_average_std = get_mean_std(fig11_qtpgs, 'average_score', 50)
fig11_lqtpg_average_runs, fig11_lqtpg_average_std = get_mean_std(fig11_lqtpgs, 'average_score', 50)

fig11_tpg_max_runs, fig11_tpg_max_runs = get_mean_std(fig11_tpgs, 'max_score', 50)
fig11_qtpg_max_runs, fig11_qtpg_max_runs = get_mean_std(fig11_qtpgs, 'max_score', 50)
fig11_lqtpg_max_runs, fig11_lqtpg_max_runs = get_mean_std(fig11_lqtpgs, 'max_score', 50)

plt.plot(fig11_tpg_average_runs, label="tpg", color='red')
plt.fill_between(range(50), fig11_tpg_average_runs-fig11_tpg_average_std, fig11_tpg_average_runs+fig11_tpg_average_std, alpha=0.2, color='red')

plt.plot(fig11_qtpg_average_runs, label="qtpg", color='blue')
plt.fill_between(range(50), fig11_qtpg_average_runs-fig11_qtpg_average_std, fig11_qtpg_average_runs+fig11_qtpg_average_std, alpha=0.2, color='blue')

plt.plot(fig11_lqtpg_average_runs, label="lqtpg", color='green')
plt.fill_between(range(50), fig11_lqtpg_average_runs-fig11_lqtpg_average_std, fig11_lqtpg_average_runs+fig11_lqtpg_average_std, alpha=0.2, color='green')

plt.title("Run Comparisons")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Fitness")
plt.ylim(-10,130)
plt.yticks(np.arange(0, 131, 25))
plt.legend()

plt.show()

# %% [markdown]
# # Figure 12 Results

# %%
fig12_tpg_1 = pd.read_csv('../results/fig12/tpg/0.csv')
fig12_tpg_2 = pd.read_csv('../results/fig12/tpg/1.csv')
fig12_tpg_3 = pd.read_csv('../results/fig12/tpg/2.csv')
fig12_tpg_4 = pd.read_csv('../results/fig12/tpg/3.csv')
fig12_tpg_5 = pd.read_csv('../results/fig12/tpg/4.csv')
fig12_tpgs = [fig12_tpg_1, fig12_tpg_2, fig12_tpg_3, fig12_tpg_4, fig12_tpg_5]

fig12_qtpg_1 = pd.read_csv('../results/fig12/qtpg/0.csv')
fig12_qtpg_2 = pd.read_csv('../results/fig12/qtpg/1.csv')
fig12_qtpg_3 = pd.read_csv('../results/fig12/qtpg/2.csv')
fig12_qtpg_4 = pd.read_csv('../results/fig12/qtpg/3.csv')
fig12_qtpg_5 = pd.read_csv('../results/fig12/qtpg/4.csv')
fig12_qtpgs = [fig12_qtpg_1, fig12_qtpg_2, fig12_qtpg_3, fig12_qtpg_4, fig12_qtpg_5]

fig12_lqtpg_1 = pd.read_csv('../results/fig12/lqtpg/0.csv')
fig12_lqtpg_2 = pd.read_csv('../results/fig12/lqtpg/1.csv')
fig12_lqtpg_3 = pd.read_csv('../results/fig12/lqtpg/2.csv')
fig12_lqtpg_4 = pd.read_csv('../results/fig12/lqtpg/3.csv')
fig12_lqtpg_5 = pd.read_csv('../results/fig12/lqtpg/4.csv')
fig12_lqtpgs = [fig12_lqtpg_1, fig12_lqtpg_2, fig12_lqtpg_3, fig12_lqtpg_4, fig12_lqtpg_5]

# %% [markdown]
# ## tpg

# %%
for i in range(len(fig12_tpgs)):
    plt.plot(fig12_tpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("tpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig12_tpgs)):
    plt.plot(fig12_tpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("gp Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## qtpg

# %%
for i in range(len(fig12_qtpgs)):
    plt.plot(fig12_qtpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("qtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig12_qtpgs)):
    plt.plot(fig12_qtpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("qtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## lqtpg

# %%
for i in range(len(fig12_lqtpgs)):
    plt.plot(fig12_lqtpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig12_lqtpgs)):
    plt.plot(fig12_lqtpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## All methods together, averaged over 5 runs

# %%
fig12_tpg_average_runs, fig12_tpg_average_std = get_mean_std(fig12_tpgs, 'average_score', 50)
fig12_qtpg_average_runs, fig12_qtpg_average_std = get_mean_std(fig12_qtpgs, 'average_score', 50)
fig12_lqtpg_average_runs, fig12_lqtpg_average_std = get_mean_std(fig12_lqtpgs, 'average_score', 50)

fig12_tpg_max_runs, fig12_tpg_max_runs = get_mean_std(fig12_tpgs, 'max_score', 50)
fig12_qtpg_max_runs, fig12_qtpg_max_runs = get_mean_std(fig12_qtpgs, 'max_score', 50)
fig12_lqtpg_max_runs, fig12_lqtpg_max_runs = get_mean_std(fig12_lqtpgs, 'max_score', 50)

plt.plot(fig12_tpg_average_runs, label="tpg", color='red')
plt.fill_between(range(50), fig12_tpg_average_runs-fig12_tpg_average_std, fig12_tpg_average_runs+fig12_tpg_average_std, alpha=0.2, color='red')

plt.plot(fig12_qtpg_average_runs, label="qtpg", color='blue')
plt.fill_between(range(50), fig12_qtpg_average_runs-fig12_qtpg_average_std, fig12_qtpg_average_runs+fig12_qtpg_average_std, alpha=0.2, color='blue')

plt.plot(fig12_lqtpg_average_runs, label="lqtpg", color='green')
plt.fill_between(range(50), fig12_lqtpg_average_runs-fig12_lqtpg_average_std, fig12_lqtpg_average_runs+fig12_lqtpg_average_std, alpha=0.2, color='green')

plt.title("Run Comparisons")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Fitness")
plt.ylim(-10,130)
plt.yticks(np.arange(0, 131, 25))
plt.legend()

plt.show()

# %% [markdown]
# # Figure 13 Results

# %%
fig13_tpg_1 = pd.read_csv('../results/fig13/tpg/0.csv')
fig13_tpg_2 = pd.read_csv('../results/fig13/tpg/1.csv')
fig13_tpg_3 = pd.read_csv('../results/fig13/tpg/2.csv')
fig13_tpg_4 = pd.read_csv('../results/fig13/tpg/3.csv')
fig13_tpg_5 = pd.read_csv('../results/fig13/tpg/4.csv')
fig13_tpgs = [fig13_tpg_1, fig13_tpg_2, fig13_tpg_3, fig13_tpg_4, fig13_tpg_5]

fig13_qtpg_1 = pd.read_csv('../results/fig13/qtpg/0.csv')
fig13_qtpg_2 = pd.read_csv('../results/fig13/qtpg/1.csv')
fig13_qtpg_3 = pd.read_csv('../results/fig13/qtpg/2.csv')
fig13_qtpg_4 = pd.read_csv('../results/fig13/qtpg/3.csv')
fig13_qtpg_5 = pd.read_csv('../results/fig13/qtpg/4.csv')
fig13_qtpgs = [fig13_qtpg_1, fig13_qtpg_2, fig13_qtpg_3, fig13_qtpg_4, fig13_qtpg_5]

fig13_lqtpg_1 = pd.read_csv('../results/fig13/lqtpg/0.csv')
fig13_lqtpg_2 = pd.read_csv('../results/fig13/lqtpg/1.csv')
fig13_lqtpg_3 = pd.read_csv('../results/fig13/lqtpg/2.csv')
fig13_lqtpg_4 = pd.read_csv('../results/fig13/lqtpg/3.csv')
fig13_lqtpg_5 = pd.read_csv('../results/fig13/lqtpg/4.csv')
fig13_lqtpgs = [fig13_lqtpg_1, fig13_lqtpg_2, fig13_lqtpg_3, fig13_lqtpg_4, fig13_lqtpg_5]

# %% [markdown]
# ## tpg

# %%
for i in range(len(fig13_tpgs)):
    plt.plot(fig13_tpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("tpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig13_tpgs)):
    plt.plot(fig13_tpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("gp Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## qtpg

# %%
for i in range(len(fig13_qtpgs)):
    plt.plot(fig13_qtpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("qtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
run = 0
plt.plot(fig13_qtpgs[run]['average_score'].tolist(), label='Run: '+str(run+1))
    
plt.title("qtpg Run " + str(run + 1))
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig13_qtpgs)):
    plt.plot(fig13_qtpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("qtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
run = 0
plt.plot(fig13_qtpgs[run]['max_score'].tolist(), label='Run: '+str(run+1))
    
plt.title("qtpg Run " + str(run + 1))
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## lqtpg

# %%
for i in range(len(fig13_lqtpgs)):
    plt.plot(fig13_lqtpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig13_lqtpgs)):
    plt.plot(fig13_lqtpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
plt.plot(fig13_lqtpgs[0]['max_score'].tolist(), label='Run: 0')
    
plt.title("lqtpg Run 0")
plt.xlabel("Generation")
plt.xlim(0,200)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
plt.plot(fig13_lqtpgs[1]['max_score'].tolist(), label='Run: 1')
    
plt.title("lqtpg Run 1")
plt.xlabel("Generation")
plt.xlim(0,200)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()

# %% [markdown]
# ## All methods together, averaged over 5 runs

# %%
fig13_tpg_average_runs, fig13_tpg_average_std = get_mean_std(fig13_tpgs, 'average_score', 50)
fig13_qtpg_average_runs, fig13_qtpg_average_std = get_mean_std(fig13_qtpgs, 'average_score', 50)
fig13_lqtpg_average_runs, fig13_lqtpg_average_std = get_mean_std(fig13_lqtpgs, 'average_score', 50)

fig13_tpg_max_runs, fig13_tpg_max_runs = get_mean_std(fig13_tpgs, 'max_score', 50)
fig13_qtpg_max_runs, fig13_qtpg_max_runs = get_mean_std(fig13_qtpgs, 'max_score', 50)
fig13_lqtpg_max_runs, fig13_lqtpg_max_runs = get_mean_std(fig13_lqtpgs, 'max_score', 50)

plt.plot(fig13_tpg_average_runs, label="tpg", color='red')
plt.fill_between(range(50), fig13_tpg_average_runs-fig13_tpg_average_std, fig13_tpg_average_runs+fig13_tpg_average_std, alpha=0.2, color='red')

plt.plot(fig13_qtpg_average_runs, label="qtpg", color='blue')
plt.fill_between(range(50), fig13_qtpg_average_runs-fig13_qtpg_average_std, fig13_qtpg_average_runs+fig13_qtpg_average_std, alpha=0.2, color='blue')

plt.plot(fig13_lqtpg_average_runs, label="lqtpg", color='green')
plt.fill_between(range(50), fig13_lqtpg_average_runs-fig13_lqtpg_average_std, fig13_lqtpg_average_runs+fig13_lqtpg_average_std, alpha=0.2, color='green')

plt.title("Run Comparisons")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Fitness")
plt.ylim(-10,130)
plt.yticks(np.arange(0, 131, 25))
plt.legend()

plt.show()

# %% [markdown]
# # Figure 9 Results

# %%
fig9_lqtpg_1 = pd.read_csv('../results/fig9/lqtpg/0.csv')
fig9_lqtpg_2 = pd.read_csv('../results/fig9/lqtpg/1.csv')
fig9_lqtpg_3 = pd.read_csv('../results/fig9/lqtpg/2.csv')
fig9_lqtpg_4 = pd.read_csv('../results/fig9/lqtpg/3.csv')
fig9_lqtpg_5 = pd.read_csv('../results/fig9/lqtpg/4.csv')
fig9_lqtpgs = [fig9_lqtpg_1, fig9_lqtpg_2, fig9_lqtpg_3, fig9_lqtpg_4, fig9_lqtpg_5]

# %% [markdown]
# ## lqtpg

# %%
for i in range(len(fig9_lqtpgs)):
    plt.plot(fig9_lqtpgs[i]['average_score'].tolist(), label='Run: '+str(i))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Average Fitness")
plt.ylim(-10,130)
plt.legend()

# %%
for i in range(len(fig9_lqtpgs)):
    plt.plot(fig9_lqtpgs[i]['max_score'].tolist(), label='Run: '+str(i+1))
    
plt.title("lqtpg Runs")
plt.xlabel("Generation")
plt.xlim(0,50)
plt.ylabel("Max Fitness")
plt.ylim(-10,130)
plt.legend()
